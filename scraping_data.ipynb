# %%
pip install google-api-python-client
# Out:
# ...
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.2 MB 799.2 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/13.2 MB 907.1 kB/s eta 0:00:14
#    -- ------------------------------------- 0.8/13.2 MB 907.1 kB/s eta 0:00:14
#    --- ------------------------------------ 1.3/13.2 MB 1.0 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.6/13.2 MB 1.1 MB/s eta 0:00:11
# ...

# %%
import googleapiclient.discovery
import pandas as pd

# API Setup
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyBJYr1Ufwn5f3xYvomqUOli7XR5ek1uoGY" 

# Inisialisasi YouTube API
yt = googleapiclient.discovery.build(api_service_name, api_version, developerKey=DEVELOPER_KEY)

# Video ID
VIDEO_ID = "z6nSQrYWJlY"

# List untuk menyimpan komentar
comments = []

# Request pertama
request = yt.commentThreads().list(
    part="snippet",
    videoId=VIDEO_ID,
    maxResults=100  # Batas maksimum per request
)

# Loop untuk mengambil semua komentar
while request:
    response = request.execute()

    for item in response.get("items", []):
        comment = item["snippet"]["topLevelComment"]["snippet"]
        comments.append([
            comment["authorDisplayName"],
            comment["textDisplay"],
            comment["publishedAt"],
            comment["likeCount"],
            comment["textOriginal"],
            item["snippet"]["isPublic"]
        ])

    # Cek apakah masih ada halaman berikutnya
    next_page_token = response.get("nextPageToken")
    if not next_page_token:
        break

    request = yt.commentThreads().list(
        part="snippet",
        videoId=VIDEO_ID,
        maxResults=100,
        pageToken=next_page_token
    )

# Simpan ke DataFrame
df = pd.DataFrame(comments, columns=["Username", "Komentar", "Timestamp", "Likes", "Original Text", "Public"])
df.to_csv("youtube_comments_api_5.csv", index=False, encoding="utf-8")

print("Scraping selesai! Data disimpan di 'youtube_comments_api_5.csv'")
# Out:
# ✅ Scraping selesai! Data disimpan di 'youtube_comments_api_5.csv'

# %%
df = pd.read_csv("youtube_comments_api.csv")
df
# Out:
#                  Username                                           Komentar  \
# 0         @blackberry1986  Coba dpr kalau mau buat undang&quot; bikin vot...
# 1     @UbaidillahAlhasani  mas adi dan bg pandji serti publik yg ada di k...
# 2          @BagasRyan-w5q  Kelas mas adi prayitno memang benar yg kalah g...
# 3       @sahrulmeltas7551  Dari sini kita faham bahwa parpol nya tidak ma...
# 4              @SadegaTri  Seneng lihat acara ini, tapi sedikit masih sda...
# ...                   ...                                                ...
# 5913          @ulfifitroh                                        Huhu :&#39;
# 5914         @mohadin5130                                           Ngeriii🔥
# 5915            @namnam6_           Selalu keren dan berbeda nih mata Najwa.
# 5916  @rahmatramadhan9940                                           Mantap👍💯
# 5917     @AqwamFadhlullah                                          first nih
#
#                  Timestamp  Likes  \
# ...

# %%
df = pd.read_csv("youtube_comments_api_2.csv")
df
# Out:
#                              Username  \
# 0                   @newrpgmobile2524
# 1                      @bagassyahroni
# 2                         @_yaelahhan
# 3                         @anonym6043
# 4                         @naisiregar
# ...                               ...
# 4651                  @mbarontuko6260
# 4652  @fajarimanisatrioajiramadha5146
# 4653                   @subhanbhai683
# 4654                        @nepo3502
# 4655                    @maharani5668
#
#                                                Komentar             Timestamp  \
# 0     Buat podcast lagi bang bahas gini ajak bang fe...  2025-03-27T01:28:19Z
# 1           RAKYAT MANA YANG DPR WAKILI??? GERAM KALI !  2025-03-27T01:21:44Z
# 2                        dagingnya dapet kocaknya dapet  2025-03-27T01:14:32Z
# 3     saatnya renaisans buat negeri merah putih soal...  2025-03-27T01:11:54Z
# 4     Senang melihat video ini, sooo happy, terima k...  2025-03-27T01:01:01Z
# ...

# %%
df = pd.read_csv("youtube_comments_api_3.csv")
df
# Out:
#                 Username                                           Komentar  \
# 0            @dewi-eo3ee  Emang ide tempo dn pdip itu serta suara2 sumba...
# 1        @GARDADAYAK-i4d  RASAKAN KAMU GERUNG 😅😅KAMU AKAN PUAS NANTI DI ...
# 2       @Sutikno23-gu7kx          GAK JADI NONTON ADA CONGORNYA RAI G JIJIK
# 3         @ErfanEfrianto  Kita cuma menunggu waktu untuk terjadi nya per...
# 4      @melvinyusufa9521         Oke gas oke gas makin bobrok kita gas 😂😂😂😂
# ...                  ...                                                ...
# 1902        @aku1774-n2t  Bersiap siaplah !!  Anda semua  memasuki kawas...
# 1903     @PumaTehnik-q5r  Walopun rocky sinis terhadap presiden tapi dia...
# 1904  @muhamadmabrur6135          Dmana letak mewakili rakyatnya Dpr jingan
# 1905        @aku1774-n2t  Bermata tapi tak melihat.<br>Bertelinga tapi t...
# 1906   @brilibrilian8905                                     Mantep banget😅
#
#                  Timestamp  Likes  \
# ...

# %%
df = pd.read_csv("youtube_comments_api_4.csv")
df
# Out:
#                     Username  \
# 0           @SepulangSekolah
# 1               @piwchanlpiw
# 2        @andrerandomart8306
# 3            @Samsunga31-i7c
# 4           @chandraaden2567
# ...                      ...
# 1546  @YeftyaPraskhaYulianto
# 1547    @bagasbaringbing9267
# 1548             @YierZizie2
# 1549         @playernoob8785
# 1550               @Kang8925
#
#                                                Komentar             Timestamp  \
# 0                     Thaksin perlu dibahas juga kah? 🤔  2025-03-26T10:22:30Z
# 1     emg org sipil mana yg bisa menangani troris? m...  2025-03-27T01:32:12Z
# 2     uda sejelas ini masi ada yg ga paham..?.. btw ...  2025-03-27T01:29:35Z
# 3     Tentara di indonesia ga ada yg perang tp banya...  2025-03-27T01:28:22Z
# 4                   Udah bener gua gak coblos Prabowo 😆  2025-03-27T01:20:12Z
# ...                                                 ...                   ...
# ...

# %%
df = pd.read_csv("youtube_comments_api_5.csv")
df
# Out:
#                  Username                                           Komentar  \
# 0      @simanjuntakjanter  Maka nya Tempo jangan punya niat untuk tidak N...
# 1            @Renaldo0007       Jadi ini penyebab di kirimya paket ??  Hadeh
# 2        @fannysepang1447                                  Bocor halus hebat
# 3        @Machfudoh-ld2ex                         Hasbunallahwaningmalwakiil
# 4     @burhainisurian9194  Jalan terus Tempo! .... Sampaikan KEBENARAN un...
# ...                   ...                                                ...
# 4555          @whoami4767                                           Oh tempe
# 4556     @firmantuhan-k9o  TIM BOCOR ALUS JANGAN TAKUT, UNTUK KEBENARAN T...
# 4557  @Local_indosuke2004                                     Presiden beban
# 4558   @andipamungkas3397  Semangat terus tempo, jangan kalah sama teror ...
# 4559  @AminahAminah-jz2nv                        ❤❤❤❤❤❤❤tempo bocor alus ❤❤❤
#
#                  Timestamp  Likes  \
# ...

# %%
import os

folder_path = "./"
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

dfs = []

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)  # Membaca CSV
    dfs.append(df)
    
merged_df = pd.concat(dfs, ignore_index=True)

merged_df.to_csv("data_komentar_youtube.csv", index=False, encoding="utf-8")

# %%
data = pd.read_csv("data_komentar_youtube.csv")
data
# Out:
#                   Username                                           Komentar  \
# 0          @blackberry1986  Coba dpr kalau mau buat undang&quot; bikin vot...
# 1      @UbaidillahAlhasani  mas adi dan bg pandji serti publik yg ada di k...
# 2           @BagasRyan-w5q  Kelas mas adi prayitno memang benar yg kalah g...
# 3        @sahrulmeltas7551  Dari sini kita faham bahwa parpol nya tidak ma...
# 4               @SadegaTri  Seneng lihat acara ini, tapi sedikit masih sda...
# ...                    ...                                                ...
# 18587          @whoami4767                                           Oh tempe
# 18588     @firmantuhan-k9o  TIM BOCOR ALUS JANGAN TAKUT, UNTUK KEBENARAN T...
# 18589  @Local_indosuke2004                                     Presiden beban
# 18590   @andipamungkas3397  Semangat terus tempo, jangan kalah sama teror ...
# 18591  @AminahAminah-jz2nv                        ❤❤❤❤❤❤❤tempo bocor alus ❤❤❤
#
# ...
